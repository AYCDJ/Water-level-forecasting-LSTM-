# %% [markdown]
# <a href="https://colab.research.google.com/github/AYCDJ/Water-level-forecasting-LSTM-/blob/main/txt_file_processing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

account = pd.read_csv("BobHallPierOct2007Sep202 - Copy.txt", sep="\s+", header=None, names = ["date", "time", "014-pwl", "014-bwl", "014-harmwl", "014-sig", "014-wsd", "014-wgt", "014-wdr"], engine='python')

# store dataframe into csv file
account.to_csv('BobHallPierOct2007Sep202 - Cleaned.csv',
			index = None)

# %%
import pandas as pd

df = pd.read_csv("BobHallPierOct2007Sep202 - Cleaned.csv")

df.dropna(subset=["014-pwl", "014-harmwl"], inplace = True)  # Drop rows with any missing values
df.to_csv('V2BobHallPierOct2007Sep202 - Cleaned.csv', index = None)

# %%
import pandas as pd

account = pd.read_csv("LexingtonOct2007Sep202noWind - Copy.txt", sep="\s+", header=None, names = ["date", "time", "014-pwl", "014-bwl", "014-harmwl", "014-sig", "014-wsd", "014-wgt", "014-wdr"], engine='python')

# store dataframe into csv file
account.to_csv('LexingtonOct2007Sep202noWind - Cleaned.csv',
			index = None)

# %%
import pandas as pd

df = pd.read_csv("LexingtonOct2007Sep202noWind - Cleaned.csv")

df.dropna(subset=["014-pwl", "014-harmwl"], inplace = True)  # Drop rows with any missing values
df.to_csv('V2LexingtonOct2007Sep202noWind - Cleaned.csv', index = None)
# Out:
# <ipython-input-11-489a2d4c394e>:3: DtypeWarning: Columns (0,1,4,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("LexingtonOct2007Sep202noWind - Cleaned.csv")

# %%
import pandas as pd

# Load the data with appropriate options to handle mixed types warning
df = pd.read_csv(
    "LexingtonOct2007Sep202noWind - Cleaned.csv",
    low_memory=False
)

# Remove rows where any column contains the value "RM"
df = df[~df.eq("RM").any(axis=1)]

# Alternatively, remove rows where a specific column (e.g., "014-pwl") contains "RM"
# df = df[df["014-pwl"] != "RM"]

# Save the cleaned data
df.to_csv("V2LexingtonOct2007Sep202noWind - Cleaned.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("V2LexingtonOct2007Sep202noWind - Cleaned.csv")

df.dropna(subset=["014-pwl", "014-harmwl"], inplace = True)  # Drop rows with any missing values
df.to_csv('V3LexingtonOct2007Sep202noWind - Cleaned.csv', index = None)
# Out:
# <ipython-input-13-7459226218fc>:3: DtypeWarning: Columns (0,1,2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("V2LexingtonOct2007Sep202noWind - Cleaned.csv")
